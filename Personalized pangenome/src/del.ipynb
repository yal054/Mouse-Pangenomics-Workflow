# %%
import os

# %%
src = f"/scratch/wzhang/projects/mouse_pg/ppmg/sim_ppr/"
dst = f"/scratch/wzhang/projects/mouse_pg/ppmg/code_repo/ppr/"


for folder in os.listdir(src):
    if not os.path.isdir(os.path.join(src, folder)):
        continue
    src_folder0 = os.path.join(src, folder)
    dst_folder0 = os.path.join(dst, folder)

    skip = False

    src_f1 = os.path.join(src_folder0, "ppr.sh")
    src_f2 = os.path.join(src_folder0, "quad_graph.sh")

    if not os.path.exists(f1) or not os.path.exists(f2):
        skip = True
        continue

    if not os.path.exists(dst_folder0):
        pass
        os.makedirs(dst_folder0)

    dst_f1 = os.path.join(dst_folder0, "ppr.sh")
    dst_f2 = os.path.join(dst_folder0, "quad_graph.sh")

    cmd1 = f"cp {src_f1} {dst_f1}"
    cmd2 = f"cp {src_f2} {dst_f2}"

    # os.system(cmd1)
    # os.system(cmd2)

    # print(src_f1, dst_f1)
    # print()
# Out:
# cp: cannot stat '/scratch/wzhang/projects/mouse_pg/ppmg/sim_ppr/OLD/ppr.sh': No such file or directory
# cp: cannot stat '/scratch/wzhang/projects/mouse_pg/ppmg/sim_ppr/OLD/quad_graph.sh': No such file or directory
# cp: cannot stat '/scratch/wzhang/projects/mouse_pg/ppmg/sim_ppr/depth1/ppr.sh': No such file or directory
# cp: cannot stat '/scratch/wzhang/projects/mouse_pg/ppmg/sim_ppr/depth1/quad_graph.sh': No such file or directory
